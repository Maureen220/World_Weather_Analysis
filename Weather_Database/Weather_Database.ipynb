# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 581

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | miyang
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | almeirim
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | iquitos
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | redmond
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | hede
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | moose factory
# Processing Record 21 of Set 1 | shrigonda
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | havre-saint-pierre
# Processing Record 24 of Set 1 | alofi
# Processing Record 25 of Set 1 | cicero dantas
# Processing Record 26 of Set 1 | san cristobal
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | nijar
# Processing Record 29 of Set 1 | ballina
# Processing Record 30 of Set 1 | olafsvik
# Processing Record 31 of Set 1 | sao felix do xingu
# Processing Record 32 of Set 1 | aberystwyth
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | hambantota
# Processing Record 35 of Set 1 | jiangyou
# Processing Record 36 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 1 | fuxin
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | opunake
# Processing Record 44 of Set 1 | axams
# Processing Record 45 of Set 1 | bridlington
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | kemijarvi
# Processing Record 48 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 1 | blackwater
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | asosa
# Processing Record 10 of Set 2 | ewa beach
# Processing Record 11 of Set 2 | dwarka
# Processing Record 12 of Set 2 | hofn
# Processing Record 13 of Set 2 | mountain home
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | mitu
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | fernley
# Processing Record 23 of Set 2 | sur
# Processing Record 24 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | jacareacanga
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 2 | boralday
# Processing Record 33 of Set 2 | ushuaia
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | kloulklubed
# Processing Record 36 of Set 2 | rawson
# Processing Record 37 of Set 2 | thinadhoo
# Processing Record 38 of Set 2 | puerto quijarro
# Processing Record 39 of Set 2 | nanakuli
# Processing Record 40 of Set 2 | kisangani
# Processing Record 41 of Set 2 | pekin
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | comodoro rivadavia
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | saurimo
# Processing Record 1 of Set 3 | pangnirtung
# Processing Record 2 of Set 3 | cayenne
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | cockburn town
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | sri aman
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | sjenica
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | keflavik
# Processing Record 11 of Set 3 | shiraoi
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | hutchinson
# Processing Record 14 of Set 3 | kroya
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 3 | itoman
# Processing Record 18 of Set 3 | puerto princesa
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | sinegorye
# Processing Record 21 of Set 3 | kieta
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | muisne
# Processing Record 24 of Set 3 | monopoli
# Processing Record 25 of Set 3 | pochutla
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | kununurra
# Processing Record 28 of Set 3 | batticaloa
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | emerald
# Processing Record 31 of Set 3 | takab
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | penzance
# Processing Record 34 of Set 3 | carballo
# Processing Record 35 of Set 3 | heze
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | columbia
# Processing Record 40 of Set 3 | puerto leguizamo
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | gua musang
# Processing Record 43 of Set 3 | port hedland
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | asau
# Processing Record 46 of Set 3 | tazovskiy
# Processing Record 47 of Set 3 | usinsk
# Processing Record 48 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 3 | hervey bay
# Processing Record 50 of Set 3 | hasaki
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | amursk
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | los llanos de aridane
# Processing Record 6 of Set 4 | vestmanna
# Processing Record 7 of Set 4 | gorey
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | arrifes
# Processing Record 10 of Set 4 | tecoanapa
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 4 | jackson
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | acajutla
# Processing Record 16 of Set 4 | altoona
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | port keats
# Processing Record 19 of Set 4 | yangjiang
# Processing Record 20 of Set 4 | dakar
# Processing Record 21 of Set 4 | tautira
# Processing Record 22 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 4 | soyo
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | locri
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | khani
# Processing Record 29 of Set 4 | archidona
# Processing Record 30 of Set 4 | teguise
# Processing Record 31 of Set 4 | sao miguel do araguaia
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | gusau
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | saint-pierre
# Processing Record 38 of Set 4 | ahuimanu
# Processing Record 39 of Set 4 | port augusta
# Processing Record 40 of Set 4 | cabedelo
# Processing Record 41 of Set 4 | flin flon
# Processing Record 42 of Set 4 | manggar
# Processing Record 43 of Set 4 | catamarca
# Processing Record 44 of Set 4 | manokwari
# Processing Record 45 of Set 4 | lensk
# Processing Record 46 of Set 4 | apen
# Processing Record 47 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 4 | horodyshche
# Processing Record 49 of Set 4 | westport
# Processing Record 50 of Set 4 | hilo
# Processing Record 1 of Set 5 | the pas
# Processing Record 2 of Set 5 | sao filipe
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | amapa
# Processing Record 6 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 5 | ziyamet
# City not found. Skipping...
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | nantucket
# Processing Record 10 of Set 5 | petrozavodsk
# Processing Record 11 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 5 | phangnga
# Processing Record 13 of Set 5 | namatanai
# Processing Record 14 of Set 5 | flinders
# Processing Record 15 of Set 5 | srivardhan
# Processing Record 16 of Set 5 | mount isa
# Processing Record 17 of Set 5 | portlethen
# Processing Record 18 of Set 5 | sioux lookout
# Processing Record 19 of Set 5 | tuao
# Processing Record 20 of Set 5 | eston
# Processing Record 21 of Set 5 | dakoro
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 5 | husavik
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 5 | boende
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | kincardine
# Processing Record 29 of Set 5 | shunyi
# Processing Record 30 of Set 5 | pakenham
# Processing Record 31 of Set 5 | kovdor
# Processing Record 32 of Set 5 | tabou
# Processing Record 33 of Set 5 | gonaives
# Processing Record 34 of Set 5 | benguela
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | buritizeiro
# Processing Record 37 of Set 5 | dicabisagan
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | camacupa
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | arlit
# Processing Record 42 of Set 5 | provo
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | nautla
# Processing Record 45 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 5 | jiaocheng
# Processing Record 47 of Set 5 | rio gallegos
# Processing Record 48 of Set 5 | ouallam
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | metro
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | oktyabrskoye
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | hobart
# Processing Record 6 of Set 6 | sobolevo
# Processing Record 7 of Set 6 | mount gambier
# Processing Record 8 of Set 6 | ayan
# Processing Record 9 of Set 6 | taoudenni
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | toora-khem
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | ormara
# Processing Record 14 of Set 6 | bud
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | alice springs
# Processing Record 17 of Set 6 | barwani
# Processing Record 18 of Set 6 | rincon
# Processing Record 19 of Set 6 | calvinia
# Processing Record 20 of Set 6 | pisco
# Processing Record 21 of Set 6 | maimon
# City not found. Skipping...
# Processing Record 22 of Set 6 | auki
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | belaya gora
# Processing Record 26 of Set 6 | guicheng
# City not found. Skipping...
# Processing Record 27 of Set 6 | smirnykh
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | balakhninskiy
# Processing Record 30 of Set 6 | necochea
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | salta
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 35 of Set 6 | pierre
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | esperance
# Processing Record 38 of Set 6 | bara
# Processing Record 39 of Set 6 | klaksvik
# Processing Record 40 of Set 6 | janakpur road
# City not found. Skipping...
# Processing Record 41 of Set 6 | kotovo
# Processing Record 42 of Set 6 | richards bay
# Processing Record 43 of Set 6 | santa maria
# Processing Record 44 of Set 6 | uglovka
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | bontang
# Processing Record 47 of Set 6 | coos bay
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 6 | chadiza
# Processing Record 1 of Set 7 | rantepao
# Processing Record 2 of Set 7 | parker
# Processing Record 3 of Set 7 | tilichiki
# Processing Record 4 of Set 7 | zhigansk
# Processing Record 5 of Set 7 | hualmay
# Processing Record 6 of Set 7 | cascais
# Processing Record 7 of Set 7 | east london
# Processing Record 8 of Set 7 | vangaindrano
# Processing Record 9 of Set 7 | krasnogvardeyskoye
# Processing Record 10 of Set 7 | sabang
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | bambous virieux
# Processing Record 13 of Set 7 | leningradskiy
# Processing Record 14 of Set 7 | wanaka
# Processing Record 15 of Set 7 | noyabrsk
# Processing Record 16 of Set 7 | la ronge
# Processing Record 17 of Set 7 | glenwood springs
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | marovoay
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | mangrol
# Processing Record 22 of Set 7 | sokolo
# Processing Record 23 of Set 7 | vermillion
# Processing Record 24 of Set 7 | narsaq
# Processing Record 25 of Set 7 | murmashi
# Processing Record 26 of Set 7 | acarau
# Processing Record 27 of Set 7 | karratha
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | elliot lake
# Processing Record 30 of Set 7 | wellington
# Processing Record 31 of Set 7 | talnakh
# Processing Record 32 of Set 7 | waingapu
# Processing Record 33 of Set 7 | kopervik
# Processing Record 34 of Set 7 | lipin bor
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | gushikawa
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | inongo
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | grand-santi
# Processing Record 41 of Set 7 | ceres
# Processing Record 42 of Set 7 | srednekolymsk
# Processing Record 43 of Set 7 | codrington
# Processing Record 44 of Set 7 | poya
# Processing Record 45 of Set 7 | houma
# Processing Record 46 of Set 7 | kitimat
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | abu kamal
# Processing Record 49 of Set 7 | champerico
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | ovsyanka
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | ketou
# Processing Record 4 of Set 8 | tokmak
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | manicore
# Processing Record 7 of Set 8 | itarema
# Processing Record 8 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 9 of Set 8 | sretensk
# Processing Record 10 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 8 | sorland
# Processing Record 12 of Set 8 | cap malheureux
# Processing Record 13 of Set 8 | waw

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua      CK -21.2078 -159.7750     73.45        94          90
# 1  Makakilo City      US  21.3469 -158.0858     83.68        56          75
# 2         Zanjan      IR  36.6736   48.4787     57.24        82          46
# 3           Hilo      US  19.7297 -155.0900     95.29        74          35
# 4      Caravelas      BR -17.7125  -39.2481     70.56        86           0
# 5     Kaitangata      NZ -46.2817  169.8464     47.26        96         100
# 6   Punta Arenas      CL -53.1500  -70.9167     39.11        93         100
# 7         Hobart      AU -42.8794  147.3294     44.26        94          75
# 8          Vaini      TO -21.2000 -175.2000     73.89        84          91
# 9    Tuktoyaktuk      CA  69.4541 -133.0374     41.63        70          77
#
#    Wind Speed Current Description
# 0        3.44          light rain
# 1       13.80       broken clouds
# 2        6.98    scattered clouds
# 3        1.99    scattered clouds
# 4        5.14           clear sky
# 5        8.63     overcast clouds
# 6        5.53          light rain
# 7        6.91          light rain
# 8       24.63     overcast clouds
# 9       14.85       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
