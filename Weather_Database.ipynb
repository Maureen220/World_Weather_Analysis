# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | makakilo city
# Processing Record 3 of Set 1 | zanjan
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | caravelas
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | havelock
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | yarada
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | shingu
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | iisalmi
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | hofn
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | husavik
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | susanville
# Processing Record 31 of Set 1 | bilibino
# Processing Record 32 of Set 1 | spring hill
# Processing Record 33 of Set 1 | alexandria
# Processing Record 34 of Set 1 | adrar
# Processing Record 35 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | minab
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | newport
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | vanimo
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | myitkyina
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 1 | blagoyevo
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | hasaki
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | sao paulo de olivenca
# Processing Record 4 of Set 2 | necochea
# Processing Record 5 of Set 2 | buzhakan
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | fort saint james
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | lata
# Processing Record 10 of Set 2 | tabou
# Processing Record 11 of Set 2 | beysehir
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | pisco
# Processing Record 14 of Set 2 | isangel
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | sorong
# Processing Record 18 of Set 2 | rawson
# Processing Record 19 of Set 2 | kaeo
# Processing Record 20 of Set 2 | kathu
# Processing Record 21 of Set 2 | touros
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | khasan
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | ixtapa
# Processing Record 28 of Set 2 | guaraniacu
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 2 | grindavik
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | westport
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | santo antonio do ica
# Processing Record 38 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | anzio
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | laiyang
# Processing Record 47 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | nome
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | sabha
# Processing Record 2 of Set 3 | luanda
# Processing Record 3 of Set 3 | knysna
# Processing Record 4 of Set 3 | barra
# Processing Record 5 of Set 3 | abu zabad
# Processing Record 6 of Set 3 | kurtamysh
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | korla
# Processing Record 12 of Set 3 | poum
# Processing Record 13 of Set 3 | teya
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | kiruna
# Processing Record 16 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 3 | surt
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | pitsunda
# Processing Record 21 of Set 3 | praia
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | nizwa
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | mitikas
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | sulphur
# Processing Record 29 of Set 3 | lima
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | gigmoto
# Processing Record 32 of Set 3 | russell
# Processing Record 33 of Set 3 | manuk mangkaw
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | devonport
# Processing Record 38 of Set 3 | san andres
# Processing Record 39 of Set 3 | sur
# Processing Record 40 of Set 3 | menongue
# Processing Record 41 of Set 3 | xichang
# Processing Record 42 of Set 3 | ushtobe
# Processing Record 43 of Set 3 | port blair
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | san vicente
# Processing Record 46 of Set 3 | hattiesburg
# Processing Record 47 of Set 3 | marystown
# Processing Record 48 of Set 3 | mehamn
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | sechura
# Processing Record 1 of Set 4 | krasnoselkup
# Processing Record 2 of Set 4 | kamensk-uralskiy
# Processing Record 3 of Set 4 | belaya gora
# Processing Record 4 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 4 | inta
# Processing Record 6 of Set 4 | sakaiminato
# Processing Record 7 of Set 4 | mount gambier
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | zhigansk
# Processing Record 10 of Set 4 | plettenberg bay
# Processing Record 11 of Set 4 | yeppoon
# Processing Record 12 of Set 4 | lasa
# Processing Record 13 of Set 4 | northam
# Processing Record 14 of Set 4 | fethiye
# Processing Record 15 of Set 4 | bilma
# Processing Record 16 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | valparaiso
# Processing Record 19 of Set 4 | turaiyur
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | imisli
# City not found. Skipping...
# Processing Record 22 of Set 4 | arys
# Processing Record 23 of Set 4 | laguna
# Processing Record 24 of Set 4 | pilibanga
# Processing Record 25 of Set 4 | kosh-agach
# Processing Record 26 of Set 4 | leer
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | inuvik
# Processing Record 29 of Set 4 | marathon
# Processing Record 30 of Set 4 | kayes
# Processing Record 31 of Set 4 | tolaga bay
# Processing Record 32 of Set 4 | mahebourg
# Processing Record 33 of Set 4 | mandalgovi
# Processing Record 34 of Set 4 | moose factory
# Processing Record 35 of Set 4 | fort nelson
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | leshukonskoye
# Processing Record 38 of Set 4 | pavlovsk
# Processing Record 39 of Set 4 | butaritari
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | cairns
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | sorland
# Processing Record 44 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | dukat
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | coahuayana
# Processing Record 50 of Set 4 | panacan
# Processing Record 1 of Set 5 | chandbali
# Processing Record 2 of Set 5 | ketchikan
# Processing Record 3 of Set 5 | fare
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | maceio
# Processing Record 6 of Set 5 | genhe
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | mionica
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | klyuchi
# Processing Record 11 of Set 5 | bluff
# Processing Record 12 of Set 5 | steinbach
# Processing Record 13 of Set 5 | balikpapan
# Processing Record 14 of Set 5 | nazilli
# Processing Record 15 of Set 5 | beloha
# Processing Record 16 of Set 5 | yerbogachen
# Processing Record 17 of Set 5 | tapejara
# Processing Record 18 of Set 5 | sheksna
# Processing Record 19 of Set 5 | manado
# Processing Record 20 of Set 5 | tuatapere
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | costa rica
# Processing Record 23 of Set 5 | fallon
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | nhulunbuy
# Processing Record 26 of Set 5 | atuona
# Processing Record 27 of Set 5 | saint-pierre
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | gainesville
# Processing Record 30 of Set 5 | miri
# Processing Record 31 of Set 5 | tibiao
# Processing Record 32 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 5 | bertoua
# Processing Record 34 of Set 5 | vestmannaeyjar
# Processing Record 35 of Set 5 | penzance
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 5 | jyvaskyla
# Processing Record 39 of Set 5 | tiksi
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | quchan
# Processing Record 42 of Set 5 | arawa
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | kenai
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | beringovskiy
# Processing Record 47 of Set 5 | nkhotakota
# Processing Record 48 of Set 5 | kavieng
# Processing Record 49 of Set 5 | carmen
# Processing Record 50 of Set 5 | iralaya
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | atar
# Processing Record 3 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 6 | catamarca
# Processing Record 5 of Set 6 | assiniboia
# Processing Record 6 of Set 6 | mizan teferi
# Processing Record 7 of Set 6 | panjakent
# Processing Record 8 of Set 6 | ambon
# Processing Record 9 of Set 6 | onguday
# Processing Record 10 of Set 6 | khani
# Processing Record 11 of Set 6 | alyangula
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | ekhabi
# Processing Record 14 of Set 6 | listvyanskiy
# Processing Record 15 of Set 6 | muros
# Processing Record 16 of Set 6 | faya
# Processing Record 17 of Set 6 | levski
# Processing Record 18 of Set 6 | baramati
# Processing Record 19 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 6 | talaja
# Processing Record 21 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | sinnamary
# Processing Record 24 of Set 6 | fereydun kenar
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | moji-mirim
# City not found. Skipping...
# Processing Record 27 of Set 6 | camana
# Processing Record 28 of Set 6 | peru
# Processing Record 29 of Set 6 | jalpa
# Processing Record 30 of Set 6 | huasahuasi
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | west wendover
# Processing Record 33 of Set 6 | williams lake
# Processing Record 34 of Set 6 | farmington
# Processing Record 35 of Set 6 | luganville
# Processing Record 36 of Set 6 | cabinda
# Processing Record 37 of Set 6 | mongoumba
# Processing Record 38 of Set 6 | puerto madryn
# Processing Record 39 of Set 6 | atasu
# Processing Record 40 of Set 6 | pinawa
# Processing Record 41 of Set 6 | tasiilaq
# Processing Record 42 of Set 6 | tuy hoa
# Processing Record 43 of Set 6 | vesoul
# Processing Record 44 of Set 6 | ayan
# Processing Record 45 of Set 6 | san patricio
# Processing Record 46 of Set 6 | mut
# Processing Record 47 of Set 6 | kiunga
# Processing Record 48 of Set 6 | anchorage
# Processing Record 49 of Set 6 | ust-shonosha
# Processing Record 50 of Set 6 | guerrero negro
# Processing Record 1 of Set 7 | paamiut
# Processing Record 2 of Set 7 | lalmohan
# Processing Record 3 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 7 | zhangye
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | labuhan
# Processing Record 7 of Set 7 | mikumi
# Processing Record 8 of Set 7 | razumnoye
# Processing Record 9 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 7 | baringo
# Processing Record 11 of Set 7 | san cristobal
# Processing Record 12 of Set 7 | mahajanga
# Processing Record 13 of Set 7 | kuching
# Processing Record 14 of Set 7 | pandhana
# Processing Record 15 of Set 7 | todos santos
# Processing Record 16 of Set 7 | komsomolskiy
# Processing Record 17 of Set 7 | kunming
# Processing Record 18 of Set 7 | pitimbu
# Processing Record 19 of Set 7 | hualmay
# Processing Record 20 of Set 7 | west bay
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | sembe
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | bardiyah
# Processing Record 25 of Set 7 | taraz
# Processing Record 26 of Set 7 | dongsheng
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | juneau
# Processing Record 29 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 30 of Set 7 | kieta
# Processing Record 31 of Set 7 | muisne
# Processing Record 32 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | brewster
# Processing Record 35 of Set 7 | severo-yeniseyskiy
# Processing Record 36 of Set 7 | tiarei
# Processing Record 37 of Set 7 | joshimath
# Processing Record 38 of Set 7 | puri
# Processing Record 39 of Set 7 | north bend
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | sibenik
# Processing Record 42 of Set 7 | kununurra
# Processing Record 43 of Set 7 | gamba
# Processing Record 44 of Set 7 | nabire
# Processing Record 45 of Set 7 | arman
# Processing Record 46 of Set 7 | santiago del estero
# Processing Record 47 of Set 7 | luau
# Processing Record 48 of Set 7 | beidao
# Processing Record 49 of Set 7 | yar-sale
# Processing Record 50 of Set 7 | kharian
# Processing Record 1 of Set 8 | camacupa
# Processing Record 2 of Set 8 | bubaque
# Processing Record 3 of Set 8 | balakhta
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | kruisfontein
# Processing Record 6 of Set 8 | visnes
# Processing Record 7 of Set 8 | uhlove
# Processing Record 8 of Set 8 | torbay
# Processing Record 9 of Set 8 | kosa
# Processing Record 10 of Set 8 | manturovo
# Processing Record 11 of Set 8 | alta floresta
# Processing Record 12 of Set 8 | lavrentiya
# Processing Record 13 of Set 8 | amot
# Processing Record 14 of Set 8 | nador
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | tazovskiy
# Processing Record 17 of Set 8 | stryn
# Processing Record 18 of Set 8 | champerico
# Processing Record 19 of Set 8 | vavuniya
# Processing Record 20 of Set 8 | saint-pascal
# City not found. Skipping...
# Processing Record 21 of Set 8 | araguacu
# Processing Record 22 of Set 8 | montrose
# Processing Record 23 of Set 8 | petatlan
# Processing Record 24 of Set 8 | rivadavia
# Processing Record 25 of Set 8 | toora-khem
# Processing Record 26 of Set 8 | aksu
# Processing Record 27 of Set 8 | honiara
# Processing Record 28 of Set 8 | betsiamites
# Processing Record 29 of Set 8 | eirunepe
# Processing Record 30 of Set 8 | ruston
# Processing Record 31 of Set 8 | sirpur
# Processing Record 32 of Set 8 | gbarnga
# Processing Record 33 of Set 8 | roma
# Processing Record 34 of Set 8 | alugan
# Processing Record 35 of Set 8 | wismar
# Processing Record 36 of Set 8 | koppies
# Processing Record 37 of Set 8 | gebze
# Processing Record 38 of Set 8 | tasquillo
# Processing Record 39 of Set 8 | waren
# Processing Record 40 of Set 8 | mozarlandia
# Processing Record 41 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 42 of Set 8 | straumen
# Processing Record 43 of Set 8 | quatre cocos
# Processing Record 44 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | hyeres
# Processing Record 46 of Set 8 | koutsouras
# Processing Record 47 of Set 8 | broome
# Processing Record 48 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 49 of Set 8 | vilcun
# Processing Record 50 of Set 8 | yarmouth
# Processing Record 1 of Set 9 | half moon bay
# Processing Record 2 of Set 9 | arandelovac
# City not found. Skipping...
# Processing Record 3 of Set 9 | hirara
# Processing Record 4 of Set 9 | pangoa
# Processing Record 5 of Set 9 | barcelos
# Processing Record 6 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 7 of Set 9 | roebourne
# Processing Record 8 of Set 9 | kearney
# Processing Record 9 of Set 9 | maningrida
# Processing Record 10 of Set 9 | tucurui
# Processing Record 11 of Set 9 | tallahassee
# Processing Record 12 of Set 9 | ejido
# Processing Record 13 of Set 9 | kangaatsiaq
# Processing Record 14 of Set 9 | myaundzha
# Processing Record 15 of Set 9 | los llanos de aridane
# Processing Record 16 of Set 9 | aljezur
# Processing Record 17 of Set 9 | helong
# Processing Record 18 of Set 9 | bandarbeyla
# Processing Record 19 of Set 9 | ahuimanu
# Processing Record 20 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 9 | vytegra
# Processing Record 22 of Set 9 | lashio
# Processing Record 23 of Set 9 | codrington
# Processing Record 24 of Set 9 | valdivia
# Processing Record 25 of Set 9 | sinnar
# Processing Record 26 of Set 9 | zvishavane
# Processing Record 27 of Set 9 | sembakung
# Processing Record 28 of Set 9 | filadelfia
# Processing Record 29 of Set 9 | olafsvik
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | itupiranga
# Processing Record 32 of Set 9 | santa cruz
# Processing Record 33 of Set 9 | kilindoni
# Processing Record 34 of Set 9 | hasanpur
# Processing Record 35 of Set 9 | cascais
# Processing Record 36 of Set 9 | mumford
# Processing Record 37 of Set 9 | hami
# Processing Record 38 of Set 9 | lang son
# Processing Record 39 of Set 9 | gohand
# Processing Record 40 of Set 9 | garowe
# Processing Record 41 of Set 9 | geraldton
# Processing Record 42 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 9 | kahului
# Processing Record 45 of Set 9 | shenzhen
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | bodden town
# Processing Record 48 of Set 9 | nantucket
# Processing Record 49 of Set 9 | ankang
# Processing Record 50 of Set 9 | havoysund
# Processing Record 1 of Set 10 | beisfjord
# Processing Record 2 of Set 10 | kazachinskoye
# Processing Record 3 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 10 | uyuni
# Processing Record 5 of Set 10 | sakaraha
# Processing Record 6 of Set 10 | evensk
# Processing Record 7 of Set 10 | santa helena
# Processing Record 8 of Set 10 | ruwi
# Processing Record 9 of Set 10 | port lincoln
# Processing Record 10 of Set 10 | salihorsk
# Processing Record 11 of Set 10 | tampere
# Processing Record 12 of Set 10 | rocha
# Processing Record 13 of Set 10 | itarema
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | sangmelima
# Processing Record 16 of Set 10 | zonguldak
# Processing Record 17 of Set 10 | machico
# Processing Record 18 of Set 10 | ambilobe
# Processing Record 19 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 20 of Set 10 | varese
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | sol-iletsk
# Processing Record 23 of Set 10 | amboasary
# Processing Record 24 of Set 10 | fairbanks
# Processing Record 25 of Set 10 | oga
# Processing Record 26 of Set 10 | lazurne
# Processing Record 27 of Set 10 | salcedo
# Processing Record 28 of Set 10 | omboue
# Processing Record 29 of Set 10 | agropoli
# Processing Record 30 of Set 10 | cayenne
# Processing Record 31 of Set 10 | arak
# Processing Record 32 of Set 10 | deep river
# Processing Record 33 of Set 10 | tumen
# Processing Record 34 of Set 10 | kewanee
# Processing Record 35 of Set 10 | la ronge
# Processing Record 36 of Set 10 | chifeng
# Processing Record 37 of Set 10 | pemba
# Processing Record 38 of Set 10 | saint-augustin
# Processing Record 39 of Set 10 | araouane
# Processing Record 40 of Set 10 | tessalit
# Processing Record 41 of Set 10 | ilulissat
# Processing Record 42 of Set 10 | cururupu
# Processing Record 43 of Set 10 | ovre ardal
# Processing Record 44 of Set 10 | north platte
# Processing Record 45 of Set 10 | velikie luki
# City not found. Skipping...
# Processing Record 46 of Set 10 | vila franca do campo
# Processing Record 47 of Set 10 | padang
# Processing Record 48 of Set 10 | jamui
# Processing Record 49 of Set 10 | macapa
# Processing Record 50 of Set 10 | bezhanitsy
# Processing Record 1 of Set 11 | viedma
# Processing Record 2 of Set 11 | solnechnyy
# Processing Record 3 of Set 11 | slonim
# Processing Record 4 of Set 11 | dubbo
# Processing Record 5 of Set 11 | ostersund
# Processing Record 6 of Set 11 | krylovskaya
# Processing Record 7 of Set 11 | samana
# Processing Record 8 of Set 11 | livenka
# Processing Record 9 of Set 11 | murgab
# Processing Record 10 of Set 11 | sayyan
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | luchegorsk
# Processing Record 13 of Set 11 | jalu
# Processing Record 14 of Set 11 | hudiksvall
# Processing Record 15 of Set 11 | sibolga
# Processing Record 16 of Set 11 | emmett
# Processing Record 17 of Set 11 | gaoual
# Processing Record 18 of Set 11 | itaobim
# Processing Record 19 of Set 11 | chuka
# Processing Record 20 of Set 11 | salisbury
# Processing Record 21 of Set 11 | shelburne
# Processing Record 22 of Set 11 | leningradskiy
# Processing Record 23 of Set 11 | metu
# Processing Record 24 of Set 11 | yumen
# Processing Record 25 of Set 11 | lebanon
# Processing Record 26 of Set 11 | usinsk
# Processing Record 27 of Set 11 | changji
# Processing Record 28 of Set 11 | buala
# Processing Record 29 of Set 11 | elko
# Processing Record 30 of Set 11 | richards bay
# Processing Record 31 of Set 11 | zalantun
# Processing Record 32 of Set 11 | virtsu
# Processing Record 33 of Set 11 | yenagoa
# Processing Record 34 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 11 | kramat
# Processing Record 36 of Set 11 | kirillov
# Processing Record 37 of Set 11 | kozhva
# Processing Record 38 of Set 11 | conakry
# Processing Record 39 of Set 11 | suntar
# Processing Record 40 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 11 | voh
# Processing Record 42 of Set 11 | deputatskiy
# Processing Record 43 of Set 11 | omsukchan
# Processing Record 44 of Set 11 | vitim
# Processing Record 45 of Set 11 | fort smith
# Processing Record 46 of Set 11 | wanning
# Processing Record 47 of Set 11 | norman wells
# Processing Record 48 of Set 11 | wadi musa
# Processing Record 49 of Set 11 | kyabram
# Processing Record 50 of Set 11 | saint-joseph
# Processing Record 1 of Set 12 | beira
# Processing Record 2 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 12 | nishihara
# Processing Record 5 of Set 12 | bloemhof
# Processing Record 6 of Set 12 | bystryy istok
# Processing Record 7 of Set 12 | takoradi
# Processing Record 8 of Set 12 | tawang
# Processing Record 9 of Set 12 | kindu
# Processing Record 10 of Set 12 | urrao
# Processing Record 11 of Set 12 | salalah
# Processing Record 12 of Set 12 | carmo do rio verde
# Processing Record 13 of Set 12 | clyde river
# Processing Record 14 of Set 12 | katsuura
# Processing Record 15 of Set 12 | bud
# Processing Record 16 of Set 12 | orodara
# Processing Record 17 of Set 12 | mangrol
# Processing Record 18 of Set 12 | raisio
# Processing Record 19 of Set 12 | terny
# Processing Record 20 of Set 12 | yakshur-bodya
# City not found. Skipping...
# Processing Record 21 of Set 12 | sidi ali
# Processing Record 22 of Set 12 | lahaina
# Processing Record 23 of Set 12 | nenjiang
# Processing Record 24 of Set 12 | kloulklubed
# Processing Record 25 of Set 12 | bentiu
# Processing Record 26 of Set 12 | san pedro
# Processing Record 27 of Set 12 | bamnet narong
# Processing Record 28 of Set 12 | rehoboth
# Processing Record 29 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 30 of Set 12 | daru
# Processing Record 31 of Set 12 | hohhot
# Processing Record 32 of Set 12 | starkville
# Processing Record 33 of Set 12 | broken hill
# Processing Record 34 of Set 12 | odienne
# Processing Record 35 of Set 12 | nowogard
# Processing Record 36 of Set 12 | tigil
# Processing Record 37 of Set 12 | urengoy
# Processing Record 38 of Set 12 | port macquarie
# Processing Record 39 of Set 12 | suzun
# Processing Record 40 of Set 12 | college
# Processing Record 41 of Set 12 | santa catalina
# Processing Record 42 of Set 12 | fuyang
# Processing Record 43 of Set 12 | ola
# Processing Record 44 of Set 12 | brookings
# Processing Record 45 of Set 12 | rebrikha
# Processing Record 46 of Set 12 | sangar
# Processing Record 47 of Set 12 | ossora
# Processing Record 48 of Set 12 | chapais
# Processing Record 49 of Set 12 | lenart
# Processing Record 50 of Set 12 | grand island
# Processing Record 1 of Set 13 | hienghene
# Processing Record 2 of Set 13 | sauk rapids
# Processing Record 3 of Set 13 | sioux lookout
# Processing Record 4 of Set 13 | nicoya
# Processing Record 5 of Set 13 | mount isa
# Processing Record 6 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 13 | ayaviri
# Processing Record 8 of Set 13 | marawi
# Processing Record 9 of Set 13 | rosario oeste
# Processing Record 10 of Set 13 | longyearbyen
# Processing Record 11 of Set 13 | igdir
# Processing Record 12 of Set 13 | ust-nera
# Processing Record 13 of Set 13 | iracoubo
# Processing Record 14 of Set 13 | aleksandrov gay
# Processing Record 15 of Set 13 | bandundu
# Processing Record 16 of Set 13 | suruc
# Processing Record 17 of Set 13 | dano
# Processing Record 18 of Set 13 | kefamenanu
# Processing Record 19 of Set 13 | margate
# Processing Record 20 of Set 13 | abonnema
# Processing Record 21 of Set 13 | baherden
# Processing Record 22 of Set 13 | tigre
# Processing Record 23 of Set 13 | zambezi
# Processing Record 24 of Set 13 | caucaia
# Processing Record 25 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 13 | marrakesh
# Processing Record 28 of Set 13 | sainte-anne-des-monts
# Processing Record 29 of Set 13 | antofagasta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 574

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua      CK -21.2078 -159.7750     73.45        94          90
# 1  Makakilo City      US  21.3469 -158.0858     83.68        56          75
# 2         Zanjan      IR  36.6736   48.4787     57.24        82          46
# 3           Hilo      US  19.7297 -155.0900     95.29        74          35
# 4      Caravelas      BR -17.7125  -39.2481     70.56        86           0
# 5     Kaitangata      NZ -46.2817  169.8464     47.26        96         100
# 6   Punta Arenas      CL -53.1500  -70.9167     39.11        93         100
# 7         Hobart      AU -42.8794  147.3294     44.26        94          75
# 8          Vaini      TO -21.2000 -175.2000     73.89        84          91
# 9    Tuktoyaktuk      CA  69.4541 -133.0374     41.63        70          77
#
#    Wind Speed Current Description
# 0        3.44          light rain
# 1       13.80       broken clouds
# 2        6.98    scattered clouds
# 3        1.99    scattered clouds
# 4        5.14           clear sky
# 5        8.63     overcast clouds
# 6        5.53          light rain
# 7        6.91          light rain
# 8       24.63     overcast clouds
# 9       14.85       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
